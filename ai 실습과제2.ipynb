# %%
import sys
print(sys.version)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]

# %%
x=100
y=100
char = 'my first code'
print(type(char))
# Out:
# <class 'str'>

# %%
print(char)
# Out:
# my first code

# %%
radius = 4.0
area = 3.14*radius**2
circle = 2.0*3.14*radius
print('면적:',area,'둘레:',circle)
# Out:
# 면적: 50.24 둘레: 25.12

# %%
radius = input('원의 반지름을 입력하세요: ')
print(type(radius))
area = 3.14*radius**2
circle = 2.0*3.14*radius
print('면적:',area,'둘레:',circle)
# Out:
# 원의 반지름을 입력하세요: 4
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6004\931676591.py in <module>
#       1 radius = input('원의 반지름을 입력하세요: ')
#       2 print(type(radius))
# ----> 3 area = 3.14*radius**2
#       4 circle = 2.0*3.14*radius
#       5 print('면적:',area,'둘레:',circle)
#
# TypeError: unsupported operand type(s) for ** or pow(): 'str' and 'int'

# %%
radius = float(input('원의 반지름을 입력하세요: '))
print(type(radius))
area = 3.14*radius**2
circle = 2.0*3.14*radius
print('면적:',area,'둘레:',circle)
# Out:
# 원의 반지름을 입력하세요: 4
# <class 'float'>
# 면적: 50.24 둘레: 25.12

# %%
a=[1,2,3]
print(a)
print(type(a))
print(a[0])
# Out:
# [1, 2, 3]
# <class 'list'>
# 1

# %%
b='1,2,3'
print(b)
print(type(b))
print(b[0])
# Out:
# 1,2,3
# <class 'str'>
# 1

# %%
c='cat'
print(c)
print(type(c))
print(c[0])
# Out:
# cat
# <class 'str'>
# c

# %%
txt4 = 'Hello ' + 'Python'
txt4
# Out:
# 'Hello Python'

# %%
txt5 = 'banana\napple\norange'
txt5
print(txt5)
# Out:
# banana
# apple
# orange

# %%
txt6 = 'banana\tapple\torange'
txt6
print(txt6)
# Out:
# banana	apple	orange

# %%
c1 = 2 + 3j
c1.real
# Out:
# 2.0

# %%
c1.imag
# Out:
# 3.0

# %%
c2 = 1 + 1j
c3 = c1*c2
c3
# Out:
# (-1+5j)

# %%
x = 100
y = 100
com = x == y
print(com)
print(type(com))
# Out:
# True
# <class 'bool'>

# %%
x = 4
y = 6
z = x&y
z
# Out:
# 4

# %%
bin(z)
# Out:
# '0b100'

# %%
print('나의 이름은 :', '이승배')
print('나의 나이는 :', '27')
print('나의 키는 :', '181')
print('10 + 20 =', 10 + 20)
print('10 * 20 =', 10 * 20)
# Out:
# 나의 이름은 : 이승배
# 나의 나이는 : 27
# 나의 키는 : 181
# 10 + 20 = 30
# 10 * 20 = 200

# %%
name = '이승배'
print('나의 이름은 :', name)
age = 27
print('나의 나이는 :', age)
height = 181
print('나의 키는 :', height, 'cm입니다')
sum = 10 + 20
print('10 + 20 =', sum)
mult = 10 * 20
print('10 * 20 =', mult)
# Out:
# 나의 이름은 : 이승배
# 나의 나이는 : 27
# 나의 키는 : 181 cm입니다
# 10 + 20 = 30
# 10 * 20 = 200

# %%
width = 20
height = 40
width =30
area = width * height
print('사각형의 면적', area)
# Out:
# 사각형의 면적 1200

# %%
123 * 456
# Out:
# 56088

# %%
1357 + 2468
# Out:
# 3825

# %%
5 ** 4
# Out:
# 625

# %%
10 / 4
# Out:
# 2.5

# %%
10 // 5
# Out:
# 2

# %%
10 % 5
# Out:
# 0

# %%
5 % 2
# Out:
# 1

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %%
3 ** 0.5
# Out:
# 1.7320508075688772

# %%
a = 8 + 2j
b = 4 + 3j

a + b
# Out:
# (12+5j)

# %%
a - b
# Out:
# (4-1j)

# %%
a * b
# Out:
# (26+32j)

# %%
a / b
# Out:
# (1.52-0.64j)

# %%
a = 1024
a >> 1
# Out:
# 512

# %%
a >> 2
# Out:
# 16

# %%
a = a >> 1
a
# Out:
# 4

# %%
a = a >> 1
a
# Out:
# 2

# %%
a = 1
a << 1
# Out:
# 2

# %%
a = a << 1
a
# Out:
# 8

# %%
a = a << 1
a
# Out:
# 128

# %%
name = input('이름을 입력하세요 : ')
print(name, '님이 입장하셨습니다.')
# Out:
# 이름을 입력하세요 : 이승배
# 이승배 님이 입장하셨습니다.

# %%
m = int(input('숫자 m을 입력하세요 : '))
n = int(input('숫자 n을 입력하세요 : '))
print('m + n =', m + n)
print('m - n =', m - n)
# Out:
# 숫자 m을 입력하세요 : 30
# 숫자 n을 입력하세요 : 50
# m + n = 80
# m - n = -20

# %%
radius = int(input('반지름을 입력하세요 : '))
print('원의 면적 = ', 3.14*radius*radius)
# Out:
# 반지름을 입력하세요 : 20
# 원의 면적 =  1256.0

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\user'
