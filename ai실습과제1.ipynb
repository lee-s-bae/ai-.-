# %%
print('hello python!')
# Out:
# hello python!

# %%
a = print('hello Lee')
print(a)
# Out:
# hello Lee
# None

# %%
def plus(a,b):
    c = a+b
    return c

ans = plus(4,3)

print(ans)
# Out:
# 7

# %%
x = 100
y = 200
x**2
# Out:
# 10000

# %%
x = 105
y = 10
x//y
# Out:
# 10

# %%
x%y
# Out:
# 5

# %%
radius = 4.0
print('원의 반지름', radius)
print('원의 면적', 3.14 * radius * radius)
print('원의 면적', 3.14 * radius**2)
print('원의 둘레', 2.0 * 3.14 * radius)
# Out:
# 원의 반지름 4.0
# 원의 면적 50.24
# 원의 면적 50.24
# 원의 둘레 25.12
